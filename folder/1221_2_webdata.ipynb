# %%
# !pip install beautifulsoup4

# %%
# 패키지 import
from bs4 import BeautifulSoup

# %%
# HTML 파일 읽어들이기
page = open("test_first.html",'r').read()
page 
# 전체가 한 문장이다.
# Out:
# '<!DOCTYPE html>\n<html>\n    <head>\n        <title>Very Simple HTML Code by PinkWink</title>\n    </head>\n    <body>\n        <div>\n            <p class="inner-text first-item" id="first">\n                Happy PinkWink.\n                <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>\n            </p>\n            <p class="inner-text second-item">\n                Happy Data Science.\n                <a href="https://www.python.org" id="py-link">Python</a>\n            </p>\n        </div>\n        <p class="outer-text first-item" id="second">\n            <b>\n                Data Science is funny.\n            </b>\n        </p>\n        <p class="outer-text">\n            <b>\n                All I need is Love.\n            </b>\n        </p>\n    </body>\n</html>'

# %%
soup = BeautifulSoup(page, 'html.parser')
soup

# parser 구조화 체계화시키는 것
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <title>Very Simple HTML Code by PinkWink</title>
# </head>
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>
# </html>

# %%
soup.head
# Out:
# <head>
# <title>Very Simple HTML Code by PinkWink</title>
# </head>

# %%
soup.body
# Out:
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>

# %% [markdown]
# beautifulSoup의 명령어
#  -> find, find_all

# %%
# 유용한 명령/함수 : find, find_all
soup.find('p')                           # 1개 , 첫번째 것을 찾을 때
soup.find_all('p')                       # p 태그 전체 찾을 때
soup.find_all(class_="outer-text")       # class 가 outer-text 찾을 때
soup.find_all(id="first")                # id 가 first인 태그 찾을 때
soup.find_all('p',chr='b', class_="outer-text")  # p 태그의 class가 outer-text 것 찾을 때

# All I need is Love를 찾기 위해서 그게 속한 제일 가까운 태그를 찾음.
# p 태그를 통해서 b태크로 갈 수 있음.
# Out:
# []

# %%
soup.find_all('b')
# Out:
# [<b>
#                  Data Science is funny.
#              </b>,
#  <b>
#                  All I need is Love.
#              </b>]

# %%
import pandas as pd

# pandas로도 홈페이지를 읽을 수 있다

# %%
url = "https://www.lh.or.kr/user/opendata/estate/list.do"
lh_web=pd.read_html(url)

# %%
lh_web[0]
# Out:
#       담당부서           연락처           공표목록  \
# 0  주거복지지원처  055-922-5525           신규입주
# 1    판매기획처  031-738-4524   투자(분양)설명회 일정
# 2    판매기획처  055-922-3325    공급관련 이자율 현황
# 3    산업단지처  055-922-4362     기업입지지원 서비스
# 4    판매기획처  055-922-3334   조성원가 공개 사업지구
# 5    판매기획처  055-922-3342           감정평가
# 6    보상기획처  055-922-3291  손실보상 관련법 및 판례
# 7    보상기획처  055-922-3291       보상 공시/공고
# 8    보상기획처  055-922-3291        손실보상 안내
# 9    보상기획처  055-922-3291        손실보상 개요
#
#                                            공표항목 공표주기             공표시기  정보위치
# 0                                  2021년 신규입주계획   매년               매월  공표매체
# 1                  "투자(분양)설명회 계획 (일시 장소 담당자 등)"   수시            자료발생시  공표매체
# 2                                   선납할인율 할부이자율   분기  3월, 6월, 9월, 12월  공표매체
# 3                  기업입지지원 서비스 개요 이용대상 내용 신청방법 등   수시            자료발생시  바로가기
# 4                                택지조성원가 공개기준 현황   수시            자료발생시  바로가기
# ...

# %%
lh_web[1]
# 애초에 lh_web[0]만 존재한 것
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-26-57d51217d3ef> in <module>
# ----> 1 lh_web[1]
#
# IndexError: list index out of range

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://finance.naver.com/marketindex/'
market_index = requests.get(url)

# %%
market_index

# Response=200 -> 서버의 응답이 정상이다.
# Out:
# <Response [200]>

# %%
market_index.content
# Out:
# b'\n<script language=javascript src="/template/head_js.naver?referer=info.finance.naver.com&menu=marketindex&submenu=market"></script>\n<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20211216210327/js/info/jindo.min.ns.1.5.3.euckr.js"></script>\n<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20211216210327/js/jindo.1.5.3.element-text-patch.js"></script>\n\n\n\t\n\t\n\t<div id="container" style="padding-bottom:0px;">\n\t\n\n\t\t\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\t\t<div class="market_include">\n\t<div class="market_data">\n\t\t<div class="market1">\n\t\t\t<div class="title">\n\t\t\t\t<h2 class="h_market1"><span>\xc8\xaf\xc0\xfc \xb0\xed\xbd\xc3 \xc8\xaf\xc0\xb2</span></h2>\n\t\t\t</div>\n\t\t\t<!-- data -->\n\t\t\t<div class="data">\n\t\t\t\t<ul class="data_lst" id="exchangeList">\n\t\t\t\t\n\t\t\t\t    \n\t\t\t\t         \n\t\t\t\t         \n\t\t\t\t         \n\t\t\t\t         \t\t\t\t         \t\t\t   
# ...

# %%
# HTML parser 이용해 soup 객체 생성
soup = BeautifulSoup(market_index.content, 'html.parser')
soup
# Out:
# <script language="javascript" src="/template/head_js.naver?referer=info.finance.naver.com&amp;menu=marketindex&amp;submenu=market"></script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20211216210327/js/info/jindo.min.ns.1.5.3.euckr.js" type="text/javascript"></script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20211216210327/js/jindo.1.5.3.element-text-patch.js" type="text/javascript"></script>
# <div id="container" style="padding-bottom:0px;">
# <div class="market_include">
# <div class="market_data">
# <div class="market1">
# <div class="title">
# <h2 class="h_market1"><span>환전 고시 환율</span></h2>
# </div>
# <!-- data -->
# <div class="data">
# <ul class="data_lst" id="exchangeList">
# <li class="on">
# <a class="head usd" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdt', '', '', event);">
# <h3 class="h_lst"><span class="blind">미국 USD</span></h3>
# <div class="head_info point_up">
# ...

# %%
soup.find_all('span',class_='value')

# class와 이름이 똑같기 때문에 class_라고 해야 함.
# Out:
# [<span class="value">1,193.00</span>,
#  <span class="value">1,049.30</span>,
#  <span class="value">1,346.72</span>,
#  <span class="value">186.92</span>,
#  <span class="value">113.4900</span>,
#  <span class="value">1.1298</span>,
#  <span class="value">1.3225</span>,
#  <span class="value">96.5400</span>,
#  <span class="value">68.61</span>,
#  <span class="value">1634.46</span>,
#  <span class="value">1793.7</span>,
#  <span class="value">68919.37</span>]
